# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/kaggle/input/email-classification-nlp/SMS_train.csv',
                encoding = 'latin1')
df.head()
# Out:
#    S. No.                                       Message_body     Label
# 0       1                         Rofl. Its true to its name  Non-Spam
# 1       2  The guy did some bitching but I acted like i'd...  Non-Spam
# 2       3  Pity, * was in mood for that. So...any other s...  Non-Spam
# 3       4               Will ü b going to esplanade fr home?  Non-Spam
# 4       5  This is the 2nd time we have tried 2 contact u...      Spam

# %%
df.loc[4,'Message_body']
# Out:
# 'This is the 2nd time we have tried 2 contact u. U have won the £750 Pound prize. 2 claim is easy, call 087187272008 NOW1! Only 10p per minute. BT-national-rate.'

# %%
df.shape
# Out:
# (957, 3)

# %%
df['Label'].value_counts()
# Out:
# Label
# Non-Spam    835
# Spam        122
# Name: count, dtype: int64

# %%
import re
import string

from tensorflow.keras.preprocessing.text import Tokenizer
from keras.utils import pad_sequences
from tensorflow.keras import models, layers
from sklearn.model_selection import train_test_split

# %% [markdown]
# **Text cleaning function**
# - Lowercase text
# - remove punctuations and numbers
# - remove stopwords
# - keep only meaningful words

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [Errno -3]
# [nltk_data]     Temporary failure in name resolution>

# %%
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  "we've",
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]','',text)
    words = text.split()
    words = [w for w in words if w not in stop_words]
    return ' '.join(words)

# %%
df1 = df.copy()

# %%
df1.head()
# Out:
#    S. No.                                       Message_body     Label
# 0       1                         Rofl. Its true to its name  Non-Spam
# 1       2  The guy did some bitching but I acted like i'd...  Non-Spam
# 2       3  Pity, * was in mood for that. So...any other s...  Non-Spam
# 3       4               Will ü b going to esplanade fr home?  Non-Spam
# 4       5  This is the 2nd time we have tried 2 contact u...      Spam

# %%
df1 = df1.drop(columns = 'S. No.')

# %%
df1['Message_body'] = df1['Message_body'].apply(clean_text)

# %%
df1.head()
# Out:
#                                         Message_body     Label
# 0                                     rofl true name  Non-Spam
# 1  guy bitching acted like id interested buying s...  Non-Spam
# 2                        pity mood soany suggestions  Non-Spam
# 3                          b going esplanade fr home  Non-Spam
# 4  nd time tried contact u u pound prize claim ea...      Spam

# %%
df1['Label'] = df1['Label'].map({'Non-Spam':0 , 'Spam':1})

# %%
df1.head()
# Out:
#                                         Message_body  Label
# 0                                     rofl true name      0
# 1  guy bitching acted like id interested buying s...      0
# 2                        pity mood soany suggestions      0
# 3                          b going esplanade fr home      0
# 4  nd time tried contact u u pound prize claim ea...      1

# %% [markdown]
# **Tokenize & pad sequences**

# %%
texts = df1['Message_body'].tolist()
labels = df1['Label'].values

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts)    #builds vocabulary

# %%
print(len(tokenizer.word_index))
# Out:
# 2925

# %%
sequences = tokenizer.texts_to_sequences(texts)
print(sequences)
# Out:
# [[1071, 243, 151], [202, 1072, 647, 11, 176, 477, 361, 126, 203, 85, 34, 362, 69, 7], [1073, 1074, 1075, 1076], [86, 31, 648, 1077, 24], [244, 14, 299, 87, 1, 1, 649, 70, 45, 204, 2, 92, 205, 478, 650], [1078, 4, 363, 7, 2, 651, 206, 46, 479, 32, 50, 39, 300, 151, 127, 1079], [301, 364], [9, 152, 302, 365, 480, 17, 4], [366, 11, 153, 35], [8, 35, 481, 1080, 1081, 61, 1082, 111, 245, 367, 246, 1083], [4, 1084, 1085, 482, 303, 20, 1086, 1087], [62, 35, 652, 69, 35], [1088, 85, 10, 483, 1089, 1090, 247], [51, 22, 2, 23], [1091, 1092, 10, 1093, 10, 154, 80, 1094, 207, 1095, 1096, 208, 303, 155, 1097, 154, 484, 1098, 653], [63, 52, 1, 485, 1099, 81], [1100, 654, 102, 368, 1101, 248, 1102, 
 1204, 95, 67], [4, 391, 705, 77, 507], [706, 707], [166, 708, 1205, 39, 1206, 32, 709, 1207, 1208, 1209, 508, 21, 710, 509, 138, 1210, 1211, 1212], [63, 1213, 1, 167, 48, 105, 711, 265], [18, 510, 36, 712, 16, 139, 75, 40, 511, 53], [94, 266, 6, 17, 6, 1214, 140, 24, 12, 126, 512, 23, 392, 6, 393, 78, 223, 713, 49, 69], [53, 1215, 1216, 1217, 128], [1218, 26, 224, 714, 1219, 1220, 225, 5, 26, 103, 39, 1221, 225, 30, 1, 7, 1222, 715], [1, 513, 267, 31, 24, 140, 22, 86, 31, 267, 23], [68, 141], [19, 168, 1223, 76, 716, 717], [68, 141], [92, 205, 221, 2, 718, 226, 188, 92, 205, 221, 268, 1224, 394, 1225, 500, 39, 21, 1226], [1227, 96, 1228, 1229], [96, 269, 322, 31, 1230, 719, 514, 269, 395, 390, 34, 48, 1231, 707], [720, 1232, 182, 31, 1233, 1234, 504, 483, 1, 49, 24, 1235, 204], [1236, 721, 396, 57, 1237, 1238, 79, 515, 105, 722, 14], [118, 129, 87, 79, 723, 270, 131, 1, 70, 142, 2, 45, 164,  ...

# %%
#list((len(x) for x in sequences))
max_len  = max(len(x) for x in sequences)
padded_sequences = pad_sequences(sequences, maxlen=max_len, padding='pre')
print(padded_sequences)
# Out:
# [[   0    0    0 ... 1071  243  151]
#  [   0    0    0 ...  362   69    7]
#  [   0    0    0 ... 1074 1075 1076]
#  ...
#  [   0    0    0 ...   84 2925  305]
#  [   0    0    0 ...   73   14  173]
#  [   0    0    0 ...    0  625  623]]

# %%
vocab_size = len(tokenizer.word_index) + 1
print("Vocab size:", vocab_size)
# Out:
# Vocab size: 2926

# %% [markdown]
# **Train test split**

# %%
X_train, X_test, y_train, y_test = train_test_split(padded_sequences,
                                                   labels, test_size=0.2,
                                                   stratify=labels)

# %% [markdown]
# **Build neural network model**

# %%
embedding_dim = 8

model = models.Sequential()                                #Define a model for neural network to learn from text

model.add(layers.Embedding(input_dim = vocab_size, output_dim = embedding_dim))     #Layer to create word embeddings

model.add(layers.Flatten())                               #Flattening the embedded vectors to feed into neural networks

model.add(layers.Dense(8))                                #Hidden layers with 5 neurons

model.add(layers.Dense(1, activation = 'sigmoid'))         #Output layer with 1 neuron as we need to predict 1 or 0

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam' , loss = 'binary_crossentropy' , metrics = ['auc'])
# Out:
# 2025-10-18 16:16:45.095263: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %% [markdown]
# **Train the model**

# %%
model.fit(X_train, y_train,
         epochs = 30,
         validation_data = (X_test, y_test))
# Out:
# Epoch 1/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - auc: 0.5020 - loss: 0.6071 - val_auc: 0.8079 - val_loss: 0.3704
# Epoch 2/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.8180 - loss: 0.3719 - val_auc: 0.8366 - val_loss: 0.3381
# Epoch 3/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.8848 - loss: 0.2939 - val_auc: 0.8700 - val_loss: 0.3078
# Epoch 4/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.9554 - loss: 0.2716 - val_auc: 0.8987 - val_loss: 0.2592
# Epoch 5/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.9776 - loss: 0.1898 - val_auc: 0.9275 - val_loss: 0.2178
# Epoch 6/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.9786 - loss: 0.1634 - val_auc: 0.9365 - val_loss: 0.1878
# Epoch 7/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.9935 - loss: 0.0960 - val_auc: 0.9453 - val_loss: 0.1612
# Epoch 8/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.9932 - loss: 0.0702 - val_auc: 0.9532 - val_loss: 0.1442
# Epoch 9/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.9911 - loss: 0.0495 - val_auc: 0.9572 - val_loss: 0.1323
# Epoch 10/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.9936 - loss: 0.0481 - val_auc: 0.9686 - val_loss: 0.1228
# Epoch 11/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.9987 - loss: 0.0249 - val_auc: 0.9704 - val_loss: 0.1166
# Epoch 12/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.9990 - loss: 0.0236 - val_auc: 0.9764 - val_loss: 0.1101
# Epoch 13/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.9996 - loss: 0.0232 - val_auc: 0.9764 - val_loss: 0.1069
# Epoch 14/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.9999 - loss: 0.0154 - val_auc: 0.9808 - val_loss: 0.1039
# Epoch 15/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 1.0000 - loss: 0.0082 - val_auc: 0.9826 - val_loss: 0.1011
# Epoch 16/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 1.0000 - loss: 0.0087 - val_auc: 0.9871 - val_loss: 0.0962
# Epoch 17/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 1.0000 - loss: 0.0073 - val_auc: 0.9872 - val_loss: 0.0947
# Epoch 18/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 1.0000 - loss: 0.0083 - val_auc: 0.9878 - val_loss: 0.0922
# Epoch 19/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 1.0000 - loss: 0.0044 - val_auc: 0.9874 - val_loss: 0.0930
# Epoch 20/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 1.0000 - loss: 0.0095 - val_auc: 0.9890 - val_loss: 0.0885
# Epoch 21/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 1.0000 - loss: 0.0035 - val_auc: 0.9883 - val_loss: 0.0908
# Epoch 22/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 1.0000 - loss: 0.0084 - val_auc: 0.9902 - val_loss: 0.0863
# Epoch 23/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 1.0000 - loss: 0.0058 - val_auc: 0.9906 - val_loss: 0.0863
# Epoch 24/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 1.0000 - loss: 0.0047 - val_auc: 0.9906 - val_loss: 0.0864
# Epoch 25/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 1.0000 - loss: 0.0029 - val_auc: 0.9906 - val_loss: 0.0856
# Epoch 26/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 1.0000 - loss: 0.0052 - val_auc: 0.9907 - val_loss: 0.0850
# Epoch 27/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 1.0000 - loss: 0.0022 - val_auc: 0.9906 - val_loss: 0.0850
# Epoch 28/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 1.0000 - loss: 0.0020 - val_auc: 0.9903 - val_loss: 0.0846
# Epoch 29/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 1.0000 - loss: 0.0015 - val_auc: 0.9906 - val_loss: 0.0843
# Epoch 30/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 1.0000 - loss: 0.0024 - val_auc: 0.9906 - val_loss: 0.0839

# %% [markdown]
# **Evaluate on test data**

# %%
model.evaluate(X_train, y_train)
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 1.0000 - loss: 0.0013
# [0.0016054328298196197, 1.0]

# %%
model.evaluate(X_test, y_test)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc: 0.9951 - loss: 0.0577
# [0.08388721197843552, 0.9905753135681152]

# %% [markdown]
# **Calculate confusion matrix and classification report of model**

# %%
X_train.shape
# Out:
# (765, 64)

# %%
ytrain_pred = [int(pred > 0.5) for pred in model.predict(X_train)]
ytest_pred = [int(pred > 0.5) for pred in model.predict(X_test)]
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# /tmp/ipykernel_37/3771153319.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ytrain_pred = [int(pred > 0.5) for pred in model.predict(X_train)]
# /tmp/ipykernel_37/3771153319.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ytest_pred = [int(pred > 0.5) for pred in model.predict(X_test)]

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_train , ytrain_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       667
#            1       1.00      1.00      1.00        98
#
#     accuracy                           1.00       765
#    macro avg       1.00      1.00      1.00       765
# weighted avg       1.00      1.00      1.00       765

# %%
print(classification_report(y_test , ytest_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98       168
#            1       0.86      0.79      0.83        24
#
#     accuracy                           0.96       192
#    macro avg       0.92      0.89      0.90       192
# weighted avg       0.96      0.96      0.96       192

# %% [markdown]
# **Test Predictions**

# %%
new_texts = [
    "Congratulation, You've won a free ticket",
    "Hey, are we meeting tommorow?",
    "This is the 2nd time we have tried 2 contact u. U have won the £750 Pound prize. 2 claim is easy, call 087187272008 NOW1! Only 10p per minute. BT-national-rate."
]

#preprocess
new_texts_cleaned = [clean_text(t) for t in new_texts]
new_seq = tokenizer.texts_to_sequences(new_texts_cleaned)
new_pad = pad_sequences(new_seq , maxlen=max_len, padding='pre')

#predictions
pred = model.predict(new_pad)
pred_labels = ['Spam' if p > 0.5 else 'Not-Spam' for p in pred]


for t,l in zip(new_texts, pred_labels):
    print(f"{t} -> {l}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Congratulation, You've won a free ticket -> Not-Spam
# Hey, are we meeting tommorow? -> Not-Spam
# This is the 2nd time we have tried 2 contact u. U have won the £750 Pound prize. 2 claim is easy, call 087187272008 NOW1! Only 10p per minute. BT-national-rate. -> Spam
